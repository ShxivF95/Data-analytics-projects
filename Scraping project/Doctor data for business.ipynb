# %% [markdown]
# ## Web scraping

# %% [markdown]
# - **Doctors of Manipal Hospital**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
base_url = 'https://www.manipalhospitals.com/saltlake/doctors-list/'

header = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36",
}

# %%
doc_name = []
Consultant = []
Qualification = []


for page_num in range(1,10):
    url = f"{base_url}{page_num}/"
    response = requests.get(url, headers = header).text

    hersoup = BeautifulSoup(response, 'lxml')

    company = hersoup.find_all('div', 'doc-profile-appoint doc-listing-appointment')


    for i in company:
        doc_name.append(i.find('h3', 'doctor_name_fetch').text.strip())
        Consultant.append(i.find('p', 'desgn').text.strip())
        Qualification.append(i.find("tbody", class_="table-qualification").find("p").text.strip())


table = pd.DataFrame({'doc_name' : doc_name, 'Consultant' : Consultant, 'Qualification' : Qualification})

# %%
table
# Out:
#                        doc_name  \
# 0               Dr. Debraj Jash
# 1                 Barnali Ghosh
# 2     Dr. Abhinibesh Chatterjee
# 3              Dr. Aditya Verma
# 4            Dr. Ajitabh Mishra
# ..                          ...
# 85  Dr. Subhankar Bandyopadhyay
# 86            Dr. Subhasish Das
# 87             Dr. Subrata Saha
# 88            Dr. Suchir Maitra
# 89         Dr. Sujit Kumar Saha
#
#                                            Consultant  \
# 0   Head of the Department - Pulmonology (Respirat...
# 1                    Consultant - Clinical Psychology
# 2              Consultant - Obstetrics and Gynecology
# 3            Consultant - Interventional Cardiologist
# 4                    Consultant - Orthopaedic Surgeon
# ..                                                ...
# 85                        Consultant -Dental Medicine
# 86                         Consultant - Ophthalmology
# 87                      Consultant - Medical Oncology
# ...

# %% [markdown]
# - **Doctors of Apollo Hospital**

# %%
url = 'https://www.apollohospitals.com/book-doctor-appointment/?page='

headerx =  {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36",
}

# %%
Doctor_Name = []
Department = []
Experince = []
Availablity = []
Timings = []


for page_no in range(1,50):
    urlx = f"{url}{page_no}"

    responsex = requests.get(urlx, headers= headerx).text

    mysoup = BeautifulSoup(responsex, 'lxml')

    network = mysoup.find_all('div', 'card-body p-lg-4 p-3 text-black')

    for i in network:
        Doctor_Name.append(i.find('h2', 'mb-1 textline1 ft-wight-1').text.strip())
        Department.append(i.find('p', 'mb-0 me-2 textline2 akscolr4 fs013 heightline-1').text.strip())
        Experince.append(i.find('p', 'mb-0 me-2 dp-col2 textline1 fs013').text.strip())
        Availablity.append(i.find('span', 'doc-weekdays').text.strip())
        Timings.append(i.find('span', 'doc-timings').text.strip())


table2 = pd.DataFrame({'Doctor_Name' : Doctor_Name, 
                       'Department' : Department,
                       'Experince' : Experince,
                       'Availablity' : Availablity,
                       'Timings' : Timings})

# %%
table2
# Out:
#              Doctor_Name                                         Department  \
# 0            Dr A Anitha     MBBS, DNB (General Medicine), DNB (Nephrology)
# 1            Dr A D Suri    MBBS ,MD Medicine, DM Nephrology,DNB Nephrology
# 2       Dr A G K Gokhale  MS, MCH(CMC Vellore), DNB, SMP(IMC), Dsc(Hons)...
# 3       Dr A Goutham Rao                MBBS, MD,DrNB MEDICAL ONCOLOGY,ECMO
# 4          Dr A Jayavelu                   MD- Gen.Medicine, DM - Neurology
# ...                  ...                                                ...
# 1227  Dr Mohini N Prasad                          MBBS, DORCP, MRCOG, FRCUG
# 1228      Dr Monica Chib                              MBBS, MD (Psychiatry)
# 1229      Dr Monica Gour  MS (Ophthalmology), Fellowship in Cornea & Mic...
# 1230     Dr Monica Malik  MBBS, DGO , DNB, Diploma in Pelvic Endoscopy (...
# 1231     Dr Monika Meena  MBBS, MD(Obstetric & Gynecology), FMAS/DMAS,& ...
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=89dbaaaa-f1f8-4526-b3aa-52bac504aa9d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
